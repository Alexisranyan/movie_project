# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm

# %%
OMdb = pd.read_csv('data/OMdb_mojo_clean.csv')

# %%
OMdb.columns
# Out:
# Index(['Actors', 'Awards', 'BoxOffice', 'Country', 'DVD', 'Director', 'Genre',
#        'IMdb_ID', 'IMdb_score', 'Language', 'Metascore', 'Plot', 'Production',
#        'RT_score', 'Rated', 'Released', 'Runtime', 'TMdb_id', 'Title', 'Type',
#        'Website', 'Year', 'actor_1', 'actor_2', 'awards', 'bo_year',
#        'bo_year_rank', 'director_1', 'director_2', 'domestic-gross',
#        'domestic-pct', 'imdbVotes', 'itunes_id', 'logBoxOffice', 'mojo_title',
#        'nominations', 'num_actor', 'num_director', 'num_genre', 'num_lang',
#        'oscar_noms', 'oscar_wins', 'overseas-gross', 'overseas-pct',
#        'search_strs', 'studio', 'titles', 'worldwide-gross', 'years'],
#       dtype='object')

# %%
OMdb.dtypes
# Out:
# Actors              object
# Awards              object
# BoxOffice          float64
# Country             object
# DVD                 object
# Director            object
# Genre               object
# IMdb_ID             object
# IMdb_score         float64
# Language            object
# Metascore          float64
# Plot                object
# Production          object
# RT_score           float64
# Rated               object
# Released            object
# Runtime            float64
# TMdb_id             object
# Title               object
# Type                object
# Website             object
# Year                 int64
# actor_1             object
# actor_2             object
# awards             float64
# bo_year            float64
# bo_year_rank       float64
# director_1          object
# director_2          object
# domestic-gross     float64
# domestic-pct       float64
# imdbVotes          float64
# itunes_id            int64
# logBoxOffice       float64
# ...

# %%
OMdb.titles
# Out:
# 0                       The Professional
# 1                 The Jungle Book (2016)
# 2               A Christmas Carol (2009)
# 3                                Z Storm
# 4                    Ghostbusters (2016)
#                      ...
# 564                     Lords of Dogtown
# 565                          Bad Boys II
# 566               Race to Witch Mountain
# 567    The Hobbit: An Unexpected Journey
# 568           Terminator 2: Judgment Day
# Name: titles, Length: 569, dtype: object

# %%
OMdb.Title
# Out:
# 0                       The Professional
# 1                        The Jungle Book
# 2                      A Christmas Carol
# 3                                Z Storm
# 4                           Ghostbusters
#                      ...
# 564                     Lords of Dogtown
# 565                          Bad Boys II
# 566               Race to Witch Mountain
# 567    The Hobbit: An Unexpected Journey
# 568           Terminator 2: Judgment Day
# Name: Title, Length: 569, dtype: object

# %%
tmdb[tmdb.title == 'The Jungle Book (2016)']
# Out:
# Empty DataFrame
# Columns: [budget, genres, homepage, id, keywords, original_language, original_title, overview, popularity, production_companies, production_countries, release_date, revenue, runtime, spoken_languages, status, tagline, title, vote_average, vote_count]
# Index: []

# %%
tmdb = pd.read_csv('data/tmdb_5000_movies.csv')

# %%
tmdb.columns
# Out:
# Index(['budget', 'genres', 'homepage', 'id', 'keywords', 'original_language',
#        'original_title', 'overview', 'popularity', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'vote_average',
#        'vote_count'],
#       dtype='object')

# %%
tmdb_new = tmdb[['title', 'budget']]

# %%
OMdb.merge(tmdb_new, how = 'left', left_on = 'titles', right_on = 'title')
# Out:
#                                                 Actors  \
# 0    Jean-Paul Belmondo, Jean Desailly, Cyrielle Cl...
# 1    Neel Sethi, Bill Murray, Ben Kingsley, Idris Elba
# 2    Matt Smith, Karen Gillan, Arthur Darvill, Mich...
# 3      Louis Koo, Ka Tung Lam, Dada Chan, Michael Wong
# 4    Zach Woods, Kristen Wiig, Ed Begley Jr., Charl...
# ..                                                 ...
# 564  John Robinson, Emile Hirsch, Rebecca De Mornay...
# 565  Martin Lawrence, Will Smith, Jordi Mollà, Gabr...
# 566  Dwayne Johnson, AnnaSophia Robb, Alexander Lud...
# 567  Ian McKellen, Martin Freeman, Richard Armitage...
# 568  Arnold Schwarzenegger, Linda Hamilton, Edward ...
#
#                                                 Awards    BoxOffice  \
# 0                                1 win & 1 nomination.          NaN
# 1       Won 1 Oscar. Another 31 wins & 54 nominations.  363995937.0
# 2                                                  NaN          NaN
# ...

# %%
all_movie = pd.read_csv('data/all_movie.csv')

# %%
all_movie.head()
# Out:
#             Cast 1               Cast 2                 Cast 3  \
# 0   Brendan Fraser          John Hannah            Maria Bello
# 1  Brett Granstaff      Diahann Carroll  Lara Jean Chorostecki
# 2   Leslie Nielsen  Nicollette Sheridan          Andy Griffith
# 3   Martina Gedeck     Moritz Bleibtreu        Johanna Wokalek
# 4     Martin Sheen        Marlon Brando          Robert Duvall
#
#               Cast 4         Cast 5                Cast 6  \
# 0      Michelle Yeoh         Jet Li          Russell Wong
# 1        Roddy Piper  T.J. McGibbon  James Preston Rogers
# 2  Marcia Gay Harden      John Ales        Barry Bostwick
# 3         Bruno Ganz      Nadja Uhl     Jan Josef Liefers
# 4   Frederic Forrest    Sam Bottoms    Laurence Fishburne
#
#                                          Description            Director 1  \
# 0  The Fast and the Furious director Rob Cohen co...             Rob Cohen
# 1  The journey of a professional wrestler who bec...      Warren P. Sonoda
# ...

# %%
all_movie.loc[:, (all_movie.columns.str.startswith('Write')) | (all_movie.columns == 'Title')]
# Out:
#                                                    Title  \
# 0                  The Mummy: Tomb of the Dragon Emperor
# 1                                       The Masked Saint
# 2                                               Spy Hard
# 3      Der Baader Meinhof Komplex (The Baader Meinhof...
# 4                                         Apocalypse Now
# ...                                                  ...
# 29805                                  Mysterious Island
# 29806                        The Absent-Minded Professor
# 29807                                             Zardoz
# 29808                                          Supernova
# 29809                                Battle: Los Angeles
#
#                     Writer 1              Writer 2              Writer 3  \
# 0               Alfred Gough          Miles Millar  Writer Not Available
# 1              Scott Crowell       Brett Granstaff  Writer Not Available
# ...

# %%
[all_movie.columns == 'Title']
# Out:
# [array([False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False,  True, False, False,
#         False, False, False])]

# %%
all_movie.columns
# Out:
# Index(['Cast 1', 'Cast 2', 'Cast 3', 'Cast 4', 'Cast 5', 'Cast 6',
#        'Description', 'Director 1', 'Director 2', 'Director 3', 'Genre',
#        'Rating', 'Release Date', 'Runtime', 'Studio', 'Title', 'Writer 1',
#        'Writer 2', 'Writer 3', 'Writer 4', 'Year'],
#       dtype='object')

# %%
100,000,000,000
